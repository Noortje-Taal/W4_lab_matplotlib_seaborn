# %% [markdown]
# # Solution lab matplotlib-seaborn

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Data

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
# There are 2 ways of doing this. Do in both ways.
# Hint: Check out the nrows, ncols, and index arguments of subplots
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way
plt.subplot(1,2,1)
plt.plot(x,y,lw=3,color="b", ls='--')
plt.subplot(1,2,2)
plt.plot(x,z,lw=3, color="r",ls='-')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot below

# %%
# your code here-2st way
'''
L.S. Correct!
'''

fig,axes=plt.subplots(1,2)
axes[0].plot(x,y,color="b", lw=3, ls='--')
axes[1].plot(x,z,color="r", lw=3, ls='-')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
# Hint: Add the figsize argument in plt.subplots()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,2))

axes[0].plot(x,y,color="blue", lw=5)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x,z,color="red", lw=3, ls='--')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# #### Plot both y=x^2 and y=exp(x) in the same plot using normal and logarithmic scale.
# Hint: Use set_xscale and set_yscale

# %%
#your code here
'''
L.S. Correct!
'''

fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2,x, np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x**2,x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")
# Out:
# Text(0.5, 1.0, 'Logarithmic scale (y)')

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Import the Fitbit2.csv file and name your dataset fitbit

# %%
'''
L.S. This does not work. Please check the accessibility of the files before handing it in. 
'''

fitbit=pd.read_csv('Fitbit2.csv')
fitbit.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1d648e5f4e6e> in <module>
# ----> 1 fitbit=pd.read_csv('Fitbit2.csv')
#       2 fitbit.head(3)
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Fitbit2.csv' does not exist: b'Fitbit2.csv'

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month?
# Is Fitbitter more active on weekend or workdays?
# All plots must be in the same jupyter notebook cell.
# Hints:
#
# Use Months_encoded and Week_or Weekend columns
# Use matplolib.pyplot object oriented API
# Set your size figure to 12,4
# Explore plt.sca
# Explore plt.xticks
# Save your figures

# %%
# Median Steps by Month_encoded
weekday_steps = fitbit['Steps'].groupby(fitbit['Months_encoded']).median()
weekday_steps.head(5)

fig,axes = plt.subplots(figsize = (12,4),nrows = 1, ncols = 2)
plt.sca(axes[0])
weekday_steps.plot(kind = 'line',linewidth=2)
plt.ylabel('Median number of steps')
plt.xlabel('Months')
plt.title('Median Steps walked by month')
plt.xticks(list(range(13)),['','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

plt.savefig('steps_months.png',bbox_inches='tight')


# Median Steps by Work_or_Weekend
plt.sca(axes[1])
weekday_steps = fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median().sort_values()
weekday_steps.plot(kind = 'bar',alpha = 0.5)
plt.ylabel('Median number of steps')
plt.title('Median Steps walked by Workdays and Weekend')
plt.xticks(list(range(2)),['Weekend','Workdays'])

plt.savefig('steps_work_weekend.png',bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-52be73e8ccda> in <module>
#       1 # Median Steps by Month_encoded
# ----> 2 weekday_steps = fitbit['Steps'].groupby(fitbit['Months_encoded']).median()
#       3 weekday_steps.head(5)
#       4
#       5 fig,axes = plt.subplots(figsize = (12,4),nrows = 1, ncols = 2)
#
# NameError: name 'fitbit' is not defined

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# Minutes Lightly Active vs Steps
# Minutes Very Active vs Steps
# Minutes Sedentary vs Steps

# %%
cols=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary','Steps']
df=fitbit[cols]
fig,axes = plt.subplots(figsize = (16,8), nrows = 1, ncols = 3)
for i in range(3):
    plt.sca(axes[i])
    plt.scatter(df.iloc[:,i],df['Steps'], alpha = 0.8)
    plt.xlabel(df.iloc[:,i].name)
    plt.ylabel('Steps')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-31e2e3d544dd> in <module>
#       1 cols=['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary','Steps']
# ----> 2 df=fitbit[cols]
#       3 fig,axes = plt.subplots(figsize = (16,8), nrows = 1, ncols = 3)
#       4 for i in range(3):
#       5     plt.sca(axes[i])
#
# NameError: name 'fitbit' is not defined

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the titanic file. Name your dataset titanic

# %%
# your code here
'''
L.S. Check the accessibility of the file. 
'''

import pandas as pd
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-2088ec4a32bd> in <module>
#       1 # your code here
#       2 import pandas as pd
# ----> 3 titanic = pd.read_csv('./titanic.csv',low_memory=False)
#       4 titanic.head(3)
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /anaconda3/envs/tensor/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./titanic.csv' does not exist: b'./titanic.csv'

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here

titanic.dtypes

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# Hint: Use Pandas select_dtypes

# %%
# your code here- numerical variable
titanic.select_dtypes(exclude=object).head(3)

# %%
#your code here- categorical variable
titanic.select_dtypes(exclude=['int','float']).head(3)

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6)
# Hint: To set the style you can use matplotlib.pyplot functions or seaborn

# %%
# your code here
plt.style.use('classic')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of the column Age

# %%
# your code here
titanic['Age'].hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f2552fdb67c3> in <module>
#       1 # your code here
# ----> 2 titanic['Age'].hist(bins=50)
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### Use subplots and plot the distribution of the Age variable with bins equal to 10,20 and 50.

# %%
# your code here
plt.subplot(1,3,1)
titanic['Age'].hist()
plt.subplot(1,3,2)
titanic['Age'].hist(bins=20)
plt.subplot(1,3,3)
titanic['Age'].hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d6a8afc3a711> in <module>
#       1 # your code here
#       2 plt.subplot(1,3,1)
# ----> 3 titanic['Age'].hist()
#       4 plt.subplot(1,3,2)
#       5 titanic['Age'].hist(bins=20)
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### How does the bin size affect your plot? Comment.

# %%
#your comment here

# %% [markdown]
# #### Use seaborn to show the distribution of the column Age

# %%
# your code here
sns.distplot(titanic['Age'],bins=30,kde=False,color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-30b7e47a2b3c> in <module>
#       1 # your code here
# ----> 2 sns.distplot(titanic['Age'],bins=30,kde=False,color='red')
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### Use the right plot to visualize the column Gender. There are 2 ways of doing it. Do it both ways.
# Hint: Use matplotlib and seaborn

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-66de301adf7a> in <module>
#       1 # your code here- 1st way
# ----> 2 titanic['Gender'].value_counts().plot(kind='bar')
#       3 plt.xlabel('Gender')
#       4 plt.ylabel('Count')
#
# NameError: name 'titanic' is not defined

# %%
# your code here- 2nd way
sns.countplot(x='Gender',data=titanic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3a458411ff40> in <module>
#       1 # your code here- 2nd way
# ----> 2 sns.countplot(x='Gender',data=titanic)
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### Use the right plot to visualize the column Pclass

# %%
# your code here
titanic['Pclass'].value_counts().plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fa18a61766f6> in <module>
#       1 # your code here
# ----> 2 titanic['Pclass'].value_counts().plot(kind='bar')
#       3 plt.xlabel('Class')
#       4 plt.ylabel('Count')
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature Age. What kind of plot would you use?

# %%
titanic.boxplot(column='Age')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9ed4a102e4a2> in <module>
# ----> 1 titanic.boxplot(column='Age')
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### What does the last plot tells you about the feature Age? Comment.

# %%
# your comment here

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the SAME plot the distribution of Age. What kind of plot would you use?

# %%
#your code here
sns.violinplot("Age", data=titanic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-07bb86e43088> in <module>
#       1 #your code here
# ----> 2 sns.violinplot("Age", data=titanic)
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### What additional information the last plot provides you about the feature Age? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between Fare and Age. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# Hint: One of the ways involves using Seaborn

# %%
#your code- 1st way

# %%
# your code-2nd way
sns.jointplot(x='Fare',y='Age',data=titanic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-69951cdf17b1> in <module>
#       1 # your code-2nd way
# ----> 2 sns.jointplot(x='Fare',y='Age',data=titanic)
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### Using Seaborn plot the correlation matrix

# %%
#your code here
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('Correlation matrix')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9e43051e6dd6> in <module>
#       1 #your code here
# ----> 2 sns.heatmap(titanic.corr(),cmap='coolwarm')
#       3 plt.title('Correlation matrix')
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### What are the most correlated feature? Comment

# %%
#your comment here

# %% [markdown]
# #### Use the right plot to display the summary statistics of the Age in function of the Pclass

# %%
#your code here
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='rainbow')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f274ae8464b4> in <module>
#       1 #your code here
# ----> 2 sns.boxplot(x='Pclass',y='Age',data=titanic,palette='rainbow')
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### Use the seaborn to plot the distribution of the Age based on the Gender
# Hint: Use Facetgrid

# %%
#your code here
g = sns.FacetGrid(data=titanic,col='Gender')
g.map(plt.hist,'Age')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-894a73277f34> in <module>
#       1 #your code here
# ----> 2 g = sns.FacetGrid(data=titanic,col='Gender')
#       3 g.map(plt.hist,'Age')
#
# NameError: name 'titanic' is not defined
